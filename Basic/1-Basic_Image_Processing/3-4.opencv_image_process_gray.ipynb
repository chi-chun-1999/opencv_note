# %% [markdown]
# # 基本影像處理 - 影像色彩空間轉換（RGB→灰階）
# ---

# %% [markdown]
# ### 第一步、載入Python套件

# %%
# 載入套件
import numpy as np
import cv2 as cv

# %% [markdown]
# ### 第二步、讀取資料夾中的影像，這裡以Lenna.png為例

# %%
# 從圖檔讀取影像像素值矩陣
# 函式輸出入 => 影像像素值矩陣 = cv.imread(圖片路徑)
img = cv.imread('./img/Lenna.png')

# %% [markdown]
# ### 第三步、色彩空間轉換
# **<font color = red>請注意! RGB彩色圖片由OpenCV讀取後，通道順序為BGR</font>**

# %%
# 色彩空間轉換，此範例為RGB→灰階
# 函式輸出入 => 輸出影像 = cv.cvtColor(輸入影像, 色彩空間轉換方式)
img_gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)

# %% [markdown]
# ### 第四步、開啟視窗並將影像顯示出來，按任意鍵將視窗關閉
# <img src="img/attachment/Lenna_gray_cmb.png" alt="Lenna_gray" align="left" width="80%">

# %%
# 顯示原始影像與灰階影像
# 函式輸出入 => cv.imshow(視窗名稱, 影像矩陣)
cv.imshow('Original Lenna', img)
cv.imshow('Grayscaled Lenna', img_gray)

# 暫停程式並在按下任意鍵後結束暫停
# 函式輸出入 => 按鍵字元編碼 = cv.waitKey(停等時間單位毫秒)
cv.waitKey(0)

# 關閉所有OpenCV的視窗
# 函式輸出入 => cv.destroyAllWindows()
cv.destroyAllWindows()
